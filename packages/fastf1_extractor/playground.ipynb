# %%
from fastf1_extractor.season_stats import get_constructor_standings, get_driver_standings

import fastf1_extractor.jolpi_client as jc

import pandas as pd

# %%
get_driver_standings()
# Out:
#    Position Number            Driver Name Points Wins Driver Code  \
# 0                1          Oscar Piastri    284    6         PIA
# 1                2           Lando Norris    275    5         NOR
# 2                3         Max Verstappen    187    2         VER
# 3                4         George Russell    172    1         RUS
# 4                5        Charles Leclerc    151    0         LEC
# 5                6         Lewis Hamilton    109    0         HAM
# 6                7  Andrea Kimi Antonelli     64    0         ANT
# 7                8        Alexander Albon     54    0         ALB
# 8                9        Nico Hülkenberg     37    0         HUL
# 9               10           Esteban Ocon     27    0         OCO
# 10              11        Fernando Alonso     26    0         ALO
# 11              12           Lance Stroll     26    0         STR
# 12              13           Isack Hadjar     22    0         HAD
# ...

# %%
jc.get_driver_standings()
# Out:
# [{'position': '1',
#   'positionText': '1',
#   'points': '284',
#   'wins': '6',
#   'Driver': {'driverId': 'piastri',
#    'permanentNumber': '81',
#    'code': 'PIA',
#    'url': 'http://en.wikipedia.org/wiki/Oscar_Piastri',
#    'givenName': 'Oscar',
#    'familyName': 'Piastri',
#    'dateOfBirth': '2001-04-06',
#    'nationality': 'Australian'},
#   'Constructors': [{'constructorId': 'mclaren',
#     'url': 'http://en.wikipedia.org/wiki/McLaren',
#     'name': 'McLaren',
#     'nationality': 'British'}]},
#  {'position': '2',
#   'positionText': '2',
#   'points': '275',
#   'wins': '5',
#   'Driver': {'driverId': 'norris',
#    'permanentNumber': '4',
#    'code': 'NOR',
#    'url': 'http://en.wikipedia.org/wiki/Lando_Norris',
#    'givenName': 'Lando',
#    'familyName': 'Norris',
#    'dateOfBirth': '1999-11-13',
#    'nationality': 'British'},
#   'Constructors': [{'constructorId': 'mclaren',
#     'url': 'http://en.wikipedia.org/wiki/McLaren',
#     'name': 'McLaren',
# ...

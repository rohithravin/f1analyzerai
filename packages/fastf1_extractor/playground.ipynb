# %%
from fastf1_extractor.season_stats import get_constructor_standings, get_driver_standings, get_season_rounds

import fastf1_extractor.jolpi_client as jc

import pandas as pd

# %%
data = get_season_rounds(2021)
data
# Out:
#    Round                  Race Name     Circuit ID      Locality  \
# 0      1         Bahrain Grand Prix        bahrain        Sakhir
# 1      2  Emilia Romagna Grand Prix          imola         Imola
# 2      3      Portuguese Grand Prix       portimao      Portimão
# 3      4         Spanish Grand Prix      catalunya      Montmeló
# 4      5          Monaco Grand Prix         monaco   Monte-Carlo
# 5      6      Azerbaijan Grand Prix           baku          Baku
# 6      7          French Grand Prix         ricard  Le Castellet
# 7      8         Styrian Grand Prix  red_bull_ring     Spielberg
# 8      9        Austrian Grand Prix  red_bull_ring     Spielberg
# 9     10         British Grand Prix    silverstone   Silverstone
# 10    11       Hungarian Grand Prix    hungaroring      Budapest
# 11    12         Belgian Grand Prix            spa           Spa
# 12    13           Dutch Grand Prix      zandvoort     Zandvoort
# ...

# %%
# Out:
#    Round                  Race Name     Circuit ID     Locality       Country  \
# 0      1      Australian Grand Prix    albert_park    Melbourne     Australia
# 1      2         Chinese Grand Prix       shanghai     Shanghai         China
# 2      3        Japanese Grand Prix         suzuka       Suzuka         Japan
# 3      4         Bahrain Grand Prix        bahrain       Sakhir       Bahrain
# 4      5   Saudi Arabian Grand Prix         jeddah       Jeddah  Saudi Arabia
# 5      6           Miami Grand Prix          miami        Miami           USA
# 6      7  Emilia Romagna Grand Prix          imola        Imola         Italy
# 7      8          Monaco Grand Prix         monaco  Monte-Carlo        Monaco
# 8      9         Spanish Grand Prix      catalunya     Montmeló         Spain
# 9     10        Canadian Grand Prix     villeneuve     Montreal        Canada
# 10    11        Austrian Grand Prix  red_bull_ring    Spielberg       Austria
# ...
